# %%
import pandas as pd
from utils import adjustDataframe, save_bigquery

# %% [markdown]
# #### Vagas

# %%
tabela = pd.read_json('../data/vagas.json')

# %%
tabela_trat = adjustDataframe(tabela, 'job_id')

# %%
tabela_trat.head()
# Out:
#    job_id informacoes_basicas_data_requicisao  \
# 0    5185                          04-05-2021
# 1    5184                          04-05-2021
# 2    5183                          04-05-2021
# 3    5182                          04-05-2021
# 4    5181                          04-05-2021
#
#   informacoes_basicas_limite_esperado_para_contratacao  \
# 0                                         00-00-0000
# 1                                         00-00-0000
# 2                                         00-00-0000
# 3                                         18-05-2021
# 4                                         00-00-0000
#
#                      informacoes_basicas_titulo_vaga  \
# 0                                   operation lead -
# 1                             consultor pp/qm sênior
# 2                              analista pl/jr c/ sql
# 3                     technical architect - 11894809
# 4  consultor sap authorization (bca) -pleno / sênior
#
# ...

# %%
save_bigquery(tabela_trat, 'fiap-4.datathon.vagas')
# Out:
# ✔ Data saved at table: fiap-4.datathon.vagas (partition: none)

# %% [markdown]
# #### Applicants

# %%
table = pd.read_json('../data/applicants.json')

# %%
table.head()
# Out:
#                                                                        31000  \
# infos_basicas              {'telefone_recado': '', 'telefone': '(11) 9704...
# informacoes_pessoais       {'data_aceite': 'Cadastro anterior ao registro...
# informacoes_profissionais  {'titulo_profissional': '', 'area_atuacao': ''...
# formacao_e_idiomas         {'nivel_academico': '', 'nivel_ingles': '', 'n...
# cargo_atual                                                               {}
#
#                                                                        31001  \
# infos_basicas              {'telefone_recado': '', 'telefone': '(11) 9372...
# informacoes_pessoais       {'data_aceite': 'Cadastro anterior ao registro...
# informacoes_profissionais  {'titulo_profissional': 'Analista Administrati...
# formacao_e_idiomas         {'nivel_academico': 'Ensino Superior Incomplet...
# cargo_atual                                                               {}
#
# ...

# %%
table_trat = adjustDataframe(table, 'applicant_id')

# %%
table_trat.head()
# Out:
#    applicant_id infos_basicas_telefone_recado infos_basicas_telefone  \
# 0         31000                           NaT        (11) 97048-2708
# 1         31001                           NaT        (11) 93723-4396
# 2         31002                           NaT        (11) 92399-9824
# 3         31003                           NaT        (11) 98100-1727
# 4         31004                           NaT        (11) 92517-2678
#
#   infos_basicas_objetivo_profissional infos_basicas_data_criacao  \
# 0                                            10-11-2021 07:29:49
# 1             analista administrativo        10-11-2021 08:56:16
# 2         administrativo | financeiro        10-11-2021 09:01:00
# 3                 área administrativa        10-11-2021 09:08:13
# 4                                            10-11-2021 09:18:46
#
#   infos_basicas_inserido_por                infos_basicas_email  \
# 0               luna correia       carolina_aparecida@gmail.com
# ...

# %%
table_trat[table_trat['applicant_id'] == 22406]
# Out:
# Empty DataFrame
# ...

# %%
save_bigquery(table_trat, 'fiap-4.datathon.applicants')
# Out:
# ✔ Data saved at table: fiap-4.datathon.applicants (partition: none)

# %% [markdown]
# #### Prospects

# %%
table = pd.read_json('../data/prospects.json')

# %%
table_trat = adjustDataframe(table, 'job_id', explode_df=True)

# %%
table_trat.job_id.value_counts()
# Out:
# job_id
# 2676     25
# 13264    25
# 2552     25
# 8221     25
# 12018    25
#          ..
# 14104     1
# 14110     1
# 14139     1
# 14147     1
# 14148     1
# Name: count, Length: 11279, dtype: Int64

# %%
table_trat[table_trat.job_id == 2676].head()
# Out:
#        job_id                          titulo_0 modalidade_0  prospect_num  \
# 10056    2676  data engineer - sr - re-232128_1                          0
# 18706    2676  data engineer - sr - re-232128_1                          1
# 25354    2676  data engineer - sr - re-232128_1                          2
# 30400    2676  data engineer - sr - re-232128_1                          3
# 34324    2676  data engineer - sr - re-232128_1                          4
#
#                          nome  codigo         situacao_candidado  \
# 10056           leonardo dias   20869  não aprovado pelo cliente
# 18706          natália farias   20817                   desistiu
# 25354       dr. matheus porto   20811       em avaliação pelo rh
# 30400      allana albuquerque   20668       em avaliação pelo rh
# 34324  dra. ana luiza freitas   20667       em avaliação pelo rh
#
#       data_candidatura ultima_atualizacao                       comentario  \
# ...

# %%
table_trat.dtypes
# Out:
# job_id                 Int64
# titulo_0              object
# modalidade_0          object
# prospect_num           Int64
# nome                  object
# codigo                 Int64
# situacao_candidado    object
# data_candidatura      object
# ultima_atualizacao    object
# comentario            object
# recrutador            object
# dtype: object

# %%
save_bigquery(table_trat, 'fiap-4.datathon.prospects')
# Out:
# ✔ Data saved at table: fiap-4.datathon.prospects (partition: none)
